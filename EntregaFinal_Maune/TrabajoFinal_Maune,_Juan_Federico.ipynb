# %% [markdown]
# <a href="https://colab.research.google.com/github/FedeM-Git/TT-2C2025-Data-Analitycs-Notebooks/blob/main/EntregaFinal_Maune/TrabajoFinal_Maune%2C_Juan_Federico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img  src="https://raw.githubusercontent.com/FedeM-Git/TT-2C2025-Data-Analitycs-Notebooks/refs/heads/main/Pre-Entrega_Maune/Pre-Entrega%20IMG.PNG" width=100%>
#
# #**MAUNE, Juan Federico**
# #**Pre-Entrega de Proyecto**
#
# **Bases de datos a utilizar:**
# - [clientes.csv](https://github.com/FedeM-Git/TT-2C2025-Data-Analitycs-Notebooks/blob/main/Pre-Entrega_Maune/datasets/clientes.csv)
# - [marketing.csv](https://github.com/FedeM-Git/TT-2C2025-Data-Analitycs-Notebooks/blob/main/Pre-Entrega_Maune/datasets/marketing.csv)
# - [ventas.csv](https://github.com/FedeM-Git/TT-2C2025-Data-Analitycs-Notebooks/blob/main/Pre-Entrega_Maune/datasets/ventas.csv)

# %% [markdown]
# #**Etapa 1: Recopilación y preparación de Datos**

# %% [markdown]
# ##***Actividad 1: Carga de los sets de datos***

# %%
# se importa pandas
import pandas as pd

# %%
# se importa data set clientes
df_clientes = pd.read_csv("https://raw.githubusercontent.com/FedeM-Git/TT-2C2025-Data-Analitycs-Notebooks/refs/heads/main/Pre-Entrega_Maune/datasets/clientes.csv")

# %%
# se importa data set marketing
df_marketing = pd.read_csv("https://raw.githubusercontent.com/FedeM-Git/TT-2C2025-Data-Analitycs-Notebooks/refs/heads/main/Pre-Entrega_Maune/datasets/marketing.csv")

# %%
# se importa data set ventas
df_ventas = pd.read_csv("https://raw.githubusercontent.com/FedeM-Git/TT-2C2025-Data-Analitycs-Notebooks/refs/heads/main/Pre-Entrega_Maune/datasets/ventas.csv")

# %% [markdown]
# ##***Actividad 2 y 3: Script Básico***

# %%
# se paso parte de los registros del set de datos de "Ventas" a una lista de diccionarios
lista_ventas = [
{'id_venta': 2824, 'producto': 'Tablet', 'precio': 74.09, 'cantidad': 5, 'fecha_venta': '45294', 'categoria': 'Electrónica'},
{'id_venta': 446, 'producto': 'Cortinas', 'precio': 62.10, 'cantidad': 4, 'fecha_venta': '45295', 'categoria': 'Decoración'},
{'id_venta': 630, 'producto': 'Adorno de pared', 'precio': 71.99, 'cantidad': 9, 'fecha_venta': '45295', 'categoria': 'Decoración'},
{'id_venta': 794, 'producto': 'Jarrón decorativo', 'precio': 96.97, 'cantidad': 7, 'fecha_venta': '45295', 'categoria': 'Decoración'},
{'id_venta': 882, 'producto': 'Cuadro decorativo', 'precio': 101.92, 'cantidad': 9, 'fecha_venta': '45295', 'categoria': 'Decoración'},
{'id_venta': 969, 'producto': 'Candelabro', 'precio': 90.70, 'cantidad': 12, 'fecha_venta': '45295', 'categoria': 'Decoración'},
{'id_venta': 1445, 'producto': 'Lavadora', 'precio': 28.41, 'cantidad': 10, 'fecha_venta': '45295', 'categoria': 'Electrodomésticos'},
{'id_venta': 1971, 'producto': 'Freidora eléctrica', 'precio': 122.25, 'cantidad': 11, 'fecha_venta': '45295', 'categoria': 'Electrodomésticos'},
{'id_venta': 2209, 'producto': 'Proyector', 'precio': 32.15, 'cantidad': 1, 'fecha_venta': '45295', 'categoria': 'Electrónica'},
{'id_venta': 256, 'producto': 'Cortinas', 'precio': 86.82, 'cantidad': 8, 'fecha_venta': '45296', 'categoria': 'Decoración'},
{'id_venta': 606, 'producto': 'Cortinas', 'precio': 106.66, 'cantidad': 11, 'fecha_venta': '45296', 'categoria': 'Decoración'},
{'id_venta': 704, 'producto': 'Jarrón decorativo', 'precio': 57.22, 'cantidad': 9, 'fecha_venta': '45296', 'categoria': 'Decoración'},
{'id_venta': 1362, 'producto': 'Heladera', 'precio': 109.49, 'cantidad': 11, 'fecha_venta': '45296', 'categoria': 'Electrodomésticos'},
{'id_venta': 2155, 'producto': 'Auriculares', 'precio': 84.80, 'cantidad': 10, 'fecha_venta': '45296', 'categoria': 'Electrónica'},
{'id_venta': 2947, 'producto': 'Cámara digital', 'precio': 107.78, 'cantidad': 3, 'fecha_venta': '45296', 'categoria': 'Electrónica'},
{'id_venta': 1495, 'producto': 'Lavadora', 'precio': 38.99, 'cantidad': 6, 'fecha_venta': '45297', 'categoria': 'Electrodomésticos'},
{'id_venta': 1572, 'producto': 'Cafetera', 'precio': 61.40, 'cantidad': 9, 'fecha_venta': '45297', 'categoria': 'Electrodomésticos'},
{'id_venta': 2180, 'producto': 'Consola de videojuegos', 'precio': 102.57, 'cantidad': 9, 'fecha_venta': '45297', 'categoria': 'Electrónica'},
{'id_venta': 2487, 'producto': 'Cámara digital', 'precio': 50.76, 'cantidad': 3, 'fecha_venta': '45297', 'categoria': 'Electrónica'},
{'id_venta': 2603, 'producto': 'Smartphone', 'precio': 87.05, 'cantidad': 5, 'fecha_venta': '45297', 'categoria': 'Electrónica'},
{'id_venta': 2885, 'producto': 'Auriculares', 'precio': 100.40, 'cantidad': 6, 'fecha_venta': '45297', 'categoria': 'Electrónica'},
{'id_venta': 17, 'producto': 'Elementos de cerámica', 'precio': 108.48, 'cantidad': 11, 'fecha_venta': '45298', 'categoria': 'Decoración'},
{'id_venta': 183, 'producto': 'Espejo decorativo', 'precio': 82.76, 'cantidad': 8, 'fecha_venta': '45298', 'categoria': 'Decoración'},
{'id_venta': 560, 'producto': 'Adorno de pared', 'precio': 57.62, 'cantidad': 6, 'fecha_venta': '45298', 'categoria': 'Decoración'},
{'id_venta': 632, 'producto': 'Cuadro decorativo', 'precio': 30.49, 'cantidad': 12, 'fecha_venta': '45298', 'categoria': 'Decoración'}
]

# %%
# ventas acumuladas de la categoría "Decoración"
ventas_decoracion = sum( [venta ['precio']* venta['cantidad']
                          for venta in lista_ventas
                          if venta['categoria']=='Decoración'])
print(f'El monto obtenido por las ventas en la categoría Decoración es de $ {ventas_decoracion}')
# Out:
# El monto obtenido por las ventas en la categoría Decoración es de $ 8530.539999999999

# %%
# ventas acumuladas de la categoría "Electrodométicos"
ventas_electrodomesticos = sum( [venta ['precio']* venta['cantidad']
                                 for venta in lista_ventas
                                 if venta['categoria']=='Electrodomésticos'])
print(f'El monto obtenido por las ventas en la categoría Electrodomésticos es de $ {ventas_electrodomesticos}')
# Out:
# El monto obtenido por las ventas en la categoría Electrodomésticos es de $ 3619.7799999999997

# %%
# ventas acumuladas de la categoría "Electrónica"
ventas_electronica = sum( [venta ['precio']* venta['cantidad']
                           for venta in lista_ventas
                           if venta['categoria']=='Electrónica'])
print(f'El monto obtenido por las ventas en la categoría Electrónica es de $ {ventas_electronica}')
# Out:
# El monto obtenido por las ventas en la categoría Electrónica es de $ 3687.0

# %%
# utilicé la AI para obtener un código que unifique los codigos anteriores en una sola sentencia
ventas_por_categoria = {
    categoria: sum(venta['precio'] * venta['cantidad']
                   for venta in lista_ventas if venta['categoria'] == categoria)
    for categoria in {venta['categoria'] for venta in lista_ventas}
}

print(ventas_por_categoria)
# Out:
# {'Electrodomésticos': 3619.7799999999997, 'Decoración': 8530.539999999999, 'Electrónica': 3687.0}

# %% [markdown]
# ## ***Actividad 4: Calidad de los Datos***
# **Análisis exploratorio con Pandas**

# %% [markdown]
# ### ***DataFrame Clientes***

# %% [markdown]
# #### **Análisis Exploratorio**

# %%
# Realizo un paneo del dataset mediante info() para conocer columnas, filas, tipos de datos y si hay datos nulos
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
#  4   ingresos    567 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 22.3+ KB

# %%
# obtengo una muestra medinte sample() para ver los datos en la tabla y ver si hay coherencia en la misma.
df_clientes.sample(10)
# Out:
#      id_cliente                  nombre  edad       ciudad  ingresos
# 97           98          Maje Stummeyer    41  Resistencia  53904.28
# 496         497           Cloris Dixson    33      Rosario  22369.56
# 244         245            Deane Tesche    22  Resistencia  29609.00
# 197         198         Juliann Keiling    62     Santa Fe  60620.67
# 113         114  Theodosia Merryweather    50      Rosario  44847.82
# 486         487          Bambi Ingleson    32     Santa Fe  31017.57
# 194         195           Brod Spuffard    45      Córdoba  15474.79
# 16           17           Minor Josephy    28     Santa Fe  47018.78
# 419         420      Carmelia Levermore    28      Rosario  36003.94
# 559         560        Woody Scourfield    31        Salta  29740.16

# %%
# utilizo describe() para obtener estadísticas de las columnas numéricas y corroborar los rangos de los datos
df_clientes.describe()
# Out:
#        id_cliente        edad      ingresos
# count  567.000000  567.000000    567.000000
# mean   284.000000   37.940035  34668.739012
# std    163.823075   10.202885  12974.531446
# min      1.000000   20.000000    170.290000
# 25%    142.500000   30.000000  26015.240000
# 50%    284.000000   37.000000  35066.830000
# 75%    425.500000   43.000000  42457.100000
# max    567.000000   81.000000  88053.010000

# %%
# utilizo value_count() sobre la columna ciudad para ver si hay ciudades cargadas de diferente forma
df_clientes['ciudad'].value_counts()
# Out:
# ciudad
# Mar del Plata            63
# Rosario                  55
# Posadas                  52
# Resistencia              50
# Córdoba                  49
# Corrientes               47
# Santa Fe                 46
# Bahía Blanca             44
# Salta                    43
# Merlo                    43
# San Miguel de Tucumán    39
# Buenos Aires             36
# Name: count, dtype: int64

# %%
# ordenos los nombres en orden ascendente para ver si hay nombres que inician con números o simbolos
df_clientes['nombre'].sort_values(ascending=True).head(20)
# Out:
# 519          Aarika Brehat
# 403             Ab Wilsher
# 349        Abbey Vanichkin
# 184            Addy Lattos
# 103        Adolphus Morton
# 333         Adrianna Fenby
# 96                Ag Ifill
# 67         Agustin Bofield
# 536          Aidan Leavens
# 327        Ailina Martelet
# 70          Aindrea Winter
# 361    Albrecht Itchingham
# 245         Aldous Stivers
# 458     Alethea Jacobovitz
# 237      Alexandra Stapley
# 544             Ali Roxbee
# 529            Alicea Clow
# 63          Alison Ianizzi
# 148       Allissa Napleton
# 0          Aloysia Screase
# Name: nombre, dtype: object

# %%
# use AI para obtener una sentencia que verifique la presencia de números o simbolos en la columna nombres
df_clientes[df_clientes["nombre"].str.contains(r"[^a-zA-ZáéíóúÁÉÍÓÚñÑ\s]", na=False)]

#Debio a que en la salida aprarecienron nombres ingles que contienen guien medio(-), apóstrofe (') y puntos (.), las entencia se cambió a :

#df_clientes[df_clientes["nombre"].str.contains(r"[^a-zA-ZáéíóúÁÉÍÓÚñÑ\s\.\-']", na=False)]
# Out:
#      id_cliente                nombre  edad                 ciudad  ingresos
# 29           30          Tedi O'Shiel    32           Bahía Blanca  44137.90
# 124         125        Bennie O'Regan    40            Resistencia  60645.26
# 153         154    My de'-Ancy Willis    43                Rosario  33105.01
# 156         157   Westbrook O'Caherny    25               Santa Fe  29982.55
# 159         160    Holly-anne Whymark    43          Mar del Plata  30588.42
# 187         188          D'arcy Creak    42           Buenos Aires  36868.84
# 246         247      Shaw Dell'Abbate    33                Posadas  41806.83
# 268         269      Carilyn O'Mailey    52           Bahía Blanca   3603.65
# 290         291  Marie-jeanne Johnson    28               Santa Fe  42821.99
# 294         295   Bette-ann Bertholin    40           Bahía Blanca  35319.17
# 417         418   Melita Watson-Brown    27  San Miguel de Tucumán  22533.03
# ...

# %%
# corroboro la auscencia de valores nulos
df_clientes.isnull().sum()
# Out:
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64

# %%
# exploro la presencia de registros duplicados
df_clientes.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ####**Observaciones**

# %% [markdown]
# - cantidad de registros: 567
# - columnas: 5
# - Precisión:
#     - los datos estan en los rangos esperados
# - Validez:
#     - los datos poseen los tipos de datos correctos
#     - los nombres no poseen números ni símbolos
# - Completitud:
#     - no se observan registros con valores nulos
# - Consistencia:
#     - las ciudades están escritas de igual forma
#     - no hay registros duplicados
# - **Cambios a realizar:**
#     - no se obserban

# %% [markdown]
# ### ***DataFrame Marketing***

# %% [markdown]
# #### **Análisis Exploratorio**

# %%
# Realizo un paneo del dataset mediante info() para conocer columnas, filas, tipos de datos y si hay datos nulos
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     object
#  5   fecha_fin     90 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.3+ KB

# %%
# obtengo una muestra medinte sample() para ver los datos en la tabla y ver si hay coherencia en la misma.
df_marketing.sample(10)
# Out:
#     id_campanha               producto  canal  costo fecha_inicio   fecha_fin
# 38           39             Candelabro  Email   6.08   17/07/2024  18/08/2024
# 79           77            Auriculares     TV   4.99   11/11/2024   6/12/2024
# 43           35        Horno eléctrico  Email   5.65   31/07/2024  29/09/2024
# 4            58               Alfombra  Email   4.25   31/03/2024  05/05/2024
# 18           76               Lavadora     TV   4.66   26/05/2024  02/07/2024
# 59           52  Elementos de cerámica  Email   5.74   09/09/2024  30/09/2024
# 54            5        Horno eléctrico   RRSS   5.16   22/08/2024  17/10/2024
# 23           83      Espejo decorativo     TV   5.24   31/05/2024  08/07/2024
# 78           61      Cuadro decorativo     TV   5.30   05/11/2024  23/12/2024
# 68            9             Candelabro   RRSS   5.32   08/10/2024  16/11/2024

# %%
# utilizo describe() para obtener estadísticas de las columnas numéricas y corroborar los rangos de los datos
df_marketing.describe()
# Out:
#        id_campanha      costo
# count    90.000000  90.000000
# mean     45.500000   4.928667
# std      26.124701   0.947750
# min       1.000000   2.950000
# 25%      23.250000   4.372500
# 50%      45.500000   4.900000
# 75%      67.750000   5.562500
# max      90.000000   7.390000

# %%
# utilizo value_count() sobre la columna "producto" para ver si hay un mismo producto está cargado con diferentes nombres
df_marketing['producto'].sort_values().value_counts()
# Out:
# producto
# Adorno de pared           3
# Alfombra                  3
# Aspiradora                3
# Auriculares               3
# Batidora                  3
# Cafetera                  3
# Candelabro                3
# Consola de videojuegos    3
# Cortinas                  3
# Cuadro decorativo         3
# Cámara digital            3
# Elementos de cerámica     3
# Espejo decorativo         3
# Freidora eléctrica        3
# Heladera                  3
# Horno eléctrico           3
# Jarrón decorativo         3
# Laptop                    3
# Lavadora                  3
# Lámpara de mesa           3
# Microondas                3
# Parlantes Bluetooth       3
# Plancha de vapor          3
# Proyector                 3
# Rincón de plantas         3
# Secadora                  3
# SmartWatch                3
# Smartphone                3
# Tablet                    3
# Televisor                 3
# Name: count, dtype: int64

# %%
# utilizo value_count() sobre la columna "canal" para ver si un canal está cargado con diferentes nombres
df_marketing['canal'].sort_values().value_counts()
# Out:
# canal
# Email    30
# RRSS     30
# TV       30
# Name: count, dtype: int64

# %%
# corroboro la auscencia de valores nulos
df_marketing.isnull().sum()
# Out:
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64

# %%
# exploro la presencia de registros duplicados
df_marketing.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ####**Observaciones**

# %% [markdown]
# - cantidad de registros: 90
# - columnas: 6
# - Precisión:
#     - los datos estan en los rangos esperados
#     - los registro de fechas no pueden ser analizado
# - Validez:
#     - las columnas 'fecha_inicio' y 'fecha_fin' tiene con Dtype Object y están en formato *dd/mm/aaaa*
# - Completitud:
#     - no se observan registros con valores nulos
# - Consistencia:
#     - las productos y canales están escritas de igual forma
#     - no hay registros duplicados
# - **Cambios a realizar:**
#     1. cambiar el Dtype de 'fecha_inicio' y 'fecha_fin' a *datetime*

# %% [markdown]
# ### ***DataFrame Ventas***

# %% [markdown]
# #### **Análisis Exploratorio**

# %%
# Realizo un paneo del dataset mediante info() para conocer columnas, filas, tipos de datos y si hay datos nulos
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3035 non-null   int64
#  1   producto     3035 non-null   object
#  2   precio       3033 non-null   object
#  3   cantidad     3033 non-null   float64
#  4   fecha_venta  3035 non-null   object
#  5   categoria    3035 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 142.4+ KB

# %%
# obtengo una muestra medinte sample() para ver los datos en la tabla y ver si hay coherencia en la misma.
df_ventas.sample(10)
# Out:
#       id_venta               producto   precio  cantidad fecha_venta  \
# 56        2501    Parlantes Bluetooth   $87.78       1.0  08/01/2024
# 423        728      Rincón de plantas   $58.34       2.0  19/02/2024
# 2443       266               Cortinas   $91.78       5.0  17/10/2024
# 643       2082              Televisor   $55.66       3.0  15/03/2024
# 568        348      Rincón de plantas   $46.49       1.0  08/03/2024
# 231       2546                 Laptop   $30.31       2.0  27/01/2024
# 1745      2326                 Laptop   $52.68      11.0  20/07/2024
# 1999       490        Adorno de pared  $108.27       8.0  22/08/2024
# 522        337  Elementos de cerámica   $92.88      10.0  02/03/2024
# 2402       382      Cuadro decorativo  $115.19       3.0  11/10/2024
#
#         categoria
# 56    Electrónica
# 423    Decoración
# 2443   Decoración
# 643   Electrónica
# 568    Decoración
# 231   Electrónica
# 1745  Electrónica
# 1999   Decoración
# 522    Decoración
# ...

# %%
# utilizo describe() para obtener estadísticas de las columnas numéricas y corroborar los rangos de los datos
df_ventas.describe()
# Out:
#           id_venta     cantidad
# count  3035.000000  3033.000000
# mean   1499.851400     6.496538
# std     866.465379     3.457250
# min       1.000000     1.000000
# 25%     748.500000     3.000000
# 50%    1502.000000     7.000000
# 75%    2249.500000     9.000000
# max    3000.000000    12.000000

# %%
# utilizo value_count() sobre la columna "productos" para ver si un producto está cargado con diferentes nombres
df_ventas['producto'].value_counts()
# Out:
# producto
# Lámpara de mesa           181
# Auriculares               147
# Microondas                135
# Cafetera                  118
# Laptop                    104
# Secadora                  103
# Jarrón decorativo         102
# Smartphone                102
# Alfombra                  102
# SmartWatch                102
# Aspiradora                102
# Cortinas                  102
# Rincón de plantas         102
# Freidora eléctrica        101
# Espejo decorativo         101
# Adorno de pared           101
# Lavadora                  100
# Consola de videojuegos    100
# Cuadro decorativo         100
# Horno eléctrico           100
# Plancha de vapor          100
# Proyector                 100
# Elementos de cerámica     100
# Batidora                  100
# Televisor                 100
# Cámara digital            100
# Parlantes Bluetooth        99
# Tablet                     58
# Heladera                   49
# Candelabro                 24
# Name: count, dtype: int64

# %%
# utilizo value_count() sobre la columna "categoria" para ver si una categoria esta cargada con diferentes nombres
df_ventas['categoria'].value_counts()
# Out:
# categoria
# Decoración           1015
# Electrónica          1012
# Electrodomésticos    1008
# Name: count, dtype: int64

# %%
# corroboro la auscencia de valores nulos
df_ventas.isnull().sum()
# Out:
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64

# %%
# visualizo los volares nulos
df_ventas[df_ventas.isnull().any(axis=1)]
# Out:
#      id_venta               producto precio  cantidad fecha_venta    categoria
# 136       627  Elementos de cerámica    NaN       NaN  17/01/2024   Decoración
# 139      2171    Parlantes Bluetooth    NaN       NaN  17/01/2024  Electrónica

# %%
# exploro la presencia de registros duplicados
df_ventas.duplicated().sum()
# Out:
# np.int64(35)

# %%
# visualizo los valores duplicados
df_ventas[df_ventas.duplicated(keep=False)].sort_values(by="id_venta")
# Out:
#      id_venta           producto  precio  cantidad fecha_venta    categoria
# 820        56           Cortinas  $66.24       5.0  05/04/2024   Decoración
# 826        56           Cortinas  $66.24       5.0  05/04/2024   Decoración
# 832       145           Alfombra  $41.72       8.0  06/04/2024   Decoración
# 844       145           Alfombra  $41.72       8.0  06/04/2024   Decoración
# 878       204  Jarrón decorativo  $94.75       1.0  08/04/2024   Decoración
# ..        ...                ...     ...       ...         ...          ...
# 830      2545        Auriculares  $32.81      11.0  05/04/2024  Electrónica
# 883      2705        Auriculares  $87.29       2.0  08/04/2024  Electrónica
# 889      2705        Auriculares  $87.29       2.0  08/04/2024  Electrónica
# 831      2778         SmartWatch  $70.66       7.0  05/04/2024  Electrónica
# 825      2778         SmartWatch  $70.66       7.0  05/04/2024  Electrónica
#
# [70 rows x 6 columns]

# %% [markdown]
# ####**Observaciones**

# %% [markdown]
# precio (object) --> float64
#
# fecha_venta (object) --> datetime
#
# cantidad (float64) --> int64
#
# los precios inclyen el simbolo ($), hay que quitarlos
#
# no obsevo valores nulos con info, hay 2 registros con valres nulos  (0.07% de los registros)
#
# hay 35 valores duplicados
#
# - cantidad de registros: 3035
# - columnas: 6
# - Precisión:
#     - los datos de *'cantidad'* están en rangos esperables. No hay valores negativos
#     - no se puede indicar la precisión de *'precio'*, *'fecha_venta'* por tener el Dtype object
# - Validez:
#     - las columnas *'precio'* y *'fecha_venta'* poseen el Dtype Object. *'precio'* posee el prefijo '$'. *'fecha_venta'* está en formato *dd/mm/aaaa*
# - Completitud:
#     - se observa 2 registros con valores nulos (2/3035 => 0.07% de los registros)
# - Consistencia:
#     - los valores de categoría y productos están escritos de igual forma
#     - hay 35 registros duplicados
# - **Cambios a realizar:**
#     1. eliminar los 2 registros con datos nulos
#     2. eliminar los registros duplicados
#     3. eliminar el prefijo '$' de los datos de *'precio'*
#     4. cambiar Dtype de *'precio'* a *float64*
#     5. cambiar Dtype de *'fecha_venta'* a *datetime*

# %% [markdown]
# #**Etapa 2: Preprocesamiento y Limpieza de Datos**

# %% [markdown]
# ##***Actividad 1: Limpieza de Datos***

# %% [markdown]
# ### ***DataFrame Marketing***

# %% [markdown]
# - **Cambios a realizar:**
#     1. cambiar el Dtype de 'fecha_inicio' y 'fecha_fin' a *datetime*

# %%
# corroboro estado inicial del dataframe
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     object
#  5   fecha_fin     90 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.3+ KB

# %%
# se convierte el campo fecha_inicio a dtype datetime
df_marketing['fecha_inicio'] = pd.to_datetime(df_marketing['fecha_inicio'], format="%d/%m/%Y")

# %%
# se convierte el campo fecha_inicio a dtype datetime
df_marketing['fecha_fin'] = pd.to_datetime(df_marketing['fecha_fin'], format="%d/%m/%Y")

# %%
# corroboro los cambios de Dtype realizados
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     datetime64[ns]
#  5   fecha_fin     90 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 4.3+ KB

# %% [markdown]
# ### ***DataFrame Ventas***

# %% [markdown]
# - **Cambios a realizar:**
#     1. eliminar los 2 registros con datos nulos
#     2. eliminar los registros duplicados
#     3. eliminar el prefijo '$' de los datos de *'precio'*
#     4. cambiar Dtype de *'precio'* a *float64*
#     5. cambiar Dtype de *'fecha_venta'* a *datetime*

# %% [markdown]
# ####*1. Eliminación de registros con datos nulos*

# %%
# corroboro presencia de registros con valores null
df_ventas[df_ventas.isnull().any(axis=1)]
# Out:
#      id_venta               producto precio  cantidad fecha_venta    categoria
# 136       627  Elementos de cerámica    NaN       NaN  17/01/2024   Decoración
# 139      2171    Parlantes Bluetooth    NaN       NaN  17/01/2024  Electrónica

# %%
# Elimino los registros con valores nulos. Aplico los cambios en el mismo DataFrame
df_ventas.dropna(inplace=True)

# %%
# corroboro la eliminación de los registros con valores null
df_ventas[df_ventas.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id_venta, producto, precio, cantidad, fecha_venta, categoria]
# Index: []

# %%
# corroboro que tengo 2 registro menos en el DataFrame Ventas
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3033 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3033 non-null   int64
#  1   producto     3033 non-null   object
#  2   precio       3033 non-null   object
#  3   cantidad     3033 non-null   float64
#  4   fecha_venta  3033 non-null   object
#  5   categoria    3033 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 165.9+ KB

# %% [markdown]
# ####*2. Eliminación de registros duplicados*

# %%
# corroboro la presencia de los registros duplicados ordanados por id_venta
df_ventas[df_ventas.duplicated(keep=False)].sort_values(by="id_venta")
# Out:
#      id_venta           producto  precio  cantidad fecha_venta    categoria
# 820        56           Cortinas  $66.24       5.0  05/04/2024   Decoración
# 826        56           Cortinas  $66.24       5.0  05/04/2024   Decoración
# 832       145           Alfombra  $41.72       8.0  06/04/2024   Decoración
# 844       145           Alfombra  $41.72       8.0  06/04/2024   Decoración
# 878       204  Jarrón decorativo  $94.75       1.0  08/04/2024   Decoración
# ..        ...                ...     ...       ...         ...          ...
# 830      2545        Auriculares  $32.81      11.0  05/04/2024  Electrónica
# 883      2705        Auriculares  $87.29       2.0  08/04/2024  Electrónica
# 889      2705        Auriculares  $87.29       2.0  08/04/2024  Electrónica
# 831      2778         SmartWatch  $70.66       7.0  05/04/2024  Electrónica
# 825      2778         SmartWatch  $70.66       7.0  05/04/2024  Electrónica
#
# [70 rows x 6 columns]

# %%
# elimino los registros duplicados, aplico los cambios en el mismo DataFrame y reinico el indice del DataFrame
df_ventas.drop_duplicates(inplace=True, ignore_index=True)

# %%
# corroboro la eliminacionde los registros duplicados
df_ventas[df_ventas.duplicated(keep=False)].sort_values(by="id_venta")
# Out:
# Empty DataFrame
# Columns: [id_venta, producto, precio, cantidad, fecha_venta, categoria]
# Index: []

# %%
# vuelvo a ver el número de registros en el DataFrame
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio       2998 non-null   object
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  2998 non-null   object
#  5   categoria    2998 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 140.7+ KB

# %% [markdown]
# ####*3. Eliminación el prefijo '$' de los datos de 'precio'*

# %%
# corroboro la presencia del prefijo '$' en la columna 'precio'
df_ventas.sample(10)
# Out:
#       id_venta             producto   precio  cantidad fecha_venta  \
# 1717      2596               Laptop   $52.44       4.0  21/07/2024
# 651       1670     Plancha de vapor  $101.57       7.0  16/03/2024
# 1010      2101  Parlantes Bluetooth   $82.23       2.0  26/04/2024
# 2385      2821  Parlantes Bluetooth  $117.62       9.0  12/10/2024
# 1886       938    Rincón de plantas   $83.79       4.0  12/08/2024
# 1218      2409            Proyector   $79.11      10.0  18/05/2024
# 2794      1656             Secadora   $42.59       7.0  04/12/2024
# 2875      1840     Plancha de vapor   $68.39       9.0  15/12/2024
# 1963       504    Jarrón decorativo   $54.62       3.0  22/08/2024
# 397       2825          Auriculares   $39.92       4.0  16/02/2024
#
#               categoria
# 1717        Electrónica
# 651   Electrodomésticos
# 1010        Electrónica
# 2385        Electrónica
# 1886         Decoración
# 1218        Electrónica
# 2794  Electrodomésticos
# 2875  Electrodomésticos
# ...

# %%
# Elimino los posibles espacios en blanco y Reeplazo el simbolo '$' por nada
df_ventas["precio"] = df_ventas["precio"].str.strip().str.replace("$", "")

# %%
# corroboro la ausencia del prefijo '$' en la columna 'precio'
df_ventas.sample(10)
# Out:
#       id_venta           producto  precio  cantidad fecha_venta  \
# 1693       155           Alfombra   79.26      10.0  19/07/2024
# 350       1436           Secadora   45.43      11.0  10/02/2024
# 1436       764  Jarrón decorativo   45.94      10.0  14/06/2024
# 2607       655           Alfombra  124.49      11.0  13/11/2024
# 558        879    Lámpara de mesa   34.26      11.0  07/03/2024
# 621       2393         Smartphone  113.88       9.0  13/03/2024
# 1864       586           Cortinas   31.36       7.0  09/08/2024
# 383       2154        Auriculares   45.97      12.0  14/02/2024
# 1797       533  Espejo decorativo   94.06       6.0  01/08/2024
# 2750       413  Espejo decorativo   60.81       7.0  30/11/2024
#
#               categoria
# 1693         Decoración
# 350   Electrodomésticos
# 1436         Decoración
# 2607         Decoración
# 558          Decoración
# 621         Electrónica
# 1864         Decoración
# 383         Electrónica
# 1797         Decoración
# ...

# %% [markdown]
# ####*4. Modificación del Dtype de *'precio'* a *float64**

# %%
# corroboro estado inicial del dataframe
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio       2998 non-null   object
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  2998 non-null   object
#  5   categoria    2998 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 140.7+ KB

# %%
# convierto los valore de la columna 'precio' al Dtype float64
df_ventas['precio'] = df_ventas['precio'].astype('float64')

# %%
# corroboro el cambio de Dtype de 'precio'
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio       2998 non-null   float64
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  2998 non-null   object
#  5   categoria    2998 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 140.7+ KB

# %% [markdown]
# ####*5. Modificación del Dtype de *'fecha_venta'* a *datetime**

# %%
# corroboro estado inicial del dataframe
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio       2998 non-null   float64
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  2998 non-null   object
#  5   categoria    2998 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 140.7+ KB

# %%
# se convierte el campo fecha_venta a dtype datetime
df_ventas['fecha_venta'] = pd.to_datetime(df_ventas['fecha_venta'], format="%d/%m/%Y")

# %%
# corroboro el cambio de Dtype de 'fecha_venta'
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio       2998 non-null   float64
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  2998 non-null   datetime64[ns]
#  5   categoria    2998 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 140.7+ KB

# %% [markdown]
# ##***Actividad 2: Transformacion de Datos***

# %% [markdown]
# Aplicar filtros y transformaciones para crear una tabla de ventas que muestre solo los productos con alto rendimiento

# %%
# se crea una nueva columna 'monto_venta' = 'precio'*'cantidad'
df_ventas['monto_venta'] = df_ventas['precio']*df_ventas['cantidad']

# %%
# visualizo la creación de la nuevo columna
df_ventas.sample(15)
# Out:
#       id_venta                producto  precio  cantidad fecha_venta  \
# 2886      1989                Batidora  124.17       7.0  2024-12-16
# 1021      1804              Aspiradora   43.25       7.0  2024-04-27
# 458       1323              Microondas   52.26       8.0  2024-02-23
# 466        930         Adorno de pared   75.13       6.0  2024-02-24
# 2788      2846                  Laptop   91.66      10.0  2024-12-03
# 959       2844                  Tablet   53.22       7.0  2024-04-20
# 2386       646                Cortinas   44.98       6.0  2024-10-13
# 2243      1228                Cafetera  115.89       4.0  2024-09-26
# 2519      2890  Consola de videojuegos  105.99       5.0  2024-10-31
# 1075      2510  Consola de videojuegos   70.04      12.0  2024-05-02
# 308       1855                Lavadora  123.28       8.0  2024-02-05
# 2316       753       Espejo decorativo  119.86       4.0  2024-10-05
# 2854      1647         Horno eléctrico   43.05      10.0  2024-12-13
# ...

# %%
# creo un nuevo DataFrame agrupando los productos y sumando los montos de las ventas
df_tabla_Ventas = df_ventas.groupby(["producto"], as_index=False)["monto_venta"].sum()

# %%
# corroboro la creación del nuevo DataFrame
df_tabla_Ventas.head()
# Out:
#           producto  monto_venta
# 0  Adorno de pared     48093.49
# 1         Alfombra     44773.06
# 2       Aspiradora     50085.86
# 3      Auriculares     74175.58
# 4         Batidora     50979.20

# %%
# corroboro métricas estadísticas de la nueva tabla
df_tabla_Ventas.describe()
# Out:
#         monto_venta
# count     30.000000
# mean   48903.117333
# std    13265.561715
# min    11128.800000
# 25%    45601.920000
# 50%    48140.245000
# 75%    51092.960000
# max    82276.380000

# %%
# corroboro fórmula para obtener el Q3
df_tabla_Ventas['monto_venta'].quantile(0.75)
# Out:
# np.float64(51092.96)

# %%
# creo un nuevo DataFrame con Filtro los datos para quedarme con los productos de cuartil superior (Q3)
df_productosTop=df_tabla_Ventas[df_tabla_Ventas['monto_venta']>df_tabla_Ventas['monto_venta'].quantile(0.75)]

# %%
# corroboro el nuevo DataFrame con los producto más Vendidos
df_productosTop
# Out:
#              producto  monto_venta
# 3         Auriculares     74175.58
# 5            Cafetera     59607.31
# 9   Cuadro decorativo     54297.60
# 16  Jarrón decorativo     51130.88
# 19    Lámpara de mesa     82276.38
# 20         Microondas     72562.89
# 25           Secadora     52115.45
# 27         Smartphone     54132.44

# %% [markdown]
# ##***Actividad 3: Agregación***

# %% [markdown]
#  Resumir las ventas por categoría de producto y analizar los ingresos generados.

# %%
#creo un nuevo DataFrame agrupando los valores por categoría y sumando los montos de las ventas
df_ventas_Categoria = df_ventas.groupby(['categoria'], as_index=False)['monto_venta'].sum()

# %%
# corroboro la creación del nuevo DataFrame
df_ventas_Categoria
# Out:
#            categoria  monto_venta
# 0         Decoración    479216.09
# 1  Electrodomésticos    505299.63
# 2        Electrónica    482577.80

# %%
# analizo el nuevo Dataframe y creo una nueva columna con el porcentaje de los montos de las ventas de cada categoría sobre el total
df_ventas_Categoria['porcentaje'] = df_ventas_Categoria['monto_venta']/df_ventas_Categoria['monto_venta'].sum()*100

# %%
# corroboro nueva columna
df_ventas_Categoria
# Out:
#            categoria  monto_venta  porcentaje
# 0         Decoración    479216.09   32.664318
# 1  Electrodomésticos    505299.63   34.442224
# 2        Electrónica    482577.80   32.893459

# %% [markdown]
# ##***Actividad 4: Integración de Datos***

# %% [markdown]
# Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.

# %% [markdown]
# ###***Análisis de los campos de los DataFrame 'Ventas' y 'Marketing' para poder integrarlos***

# %%
# repaso las columnas del DataFrame Ventas
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio       2998 non-null   float64
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  2998 non-null   datetime64[ns]
#  5   categoria    2998 non-null   object
#  6   monto_venta  2998 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 164.1+ KB

# %%
# repaso las columnas del DataFrame Marketin
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     datetime64[ns]
#  5   fecha_fin     90 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 4.3+ KB

# %% [markdown]
# Ambos DataFrame comparten la categoría *'producto'* la cual puede ser utilizada para agrupar los DataFrame

# %% [markdown]
# ###***Análisis del campo 'producto' en los DataFrame 'Ventas' y 'Marketing'***

# %%
# corroboro que los productos de ambos DataFrame sean los mismos
df_marketing['producto'].sort_values().unique() == df_ventas['producto'].sort_values().unique()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %% [markdown]
# **Observación:**
# - ambos DataFrame comparten los mismos productos.

# %% [markdown]
# ####***DataFrame 'Marketing'***

# %%
# vemos cuantas veces se repite cada paroducto
df_marketing['producto'].sort_values().value_counts()
# Out:
# producto
# Adorno de pared           3
# Alfombra                  3
# Aspiradora                3
# Auriculares               3
# Batidora                  3
# Cafetera                  3
# Candelabro                3
# Consola de videojuegos    3
# Cortinas                  3
# Cuadro decorativo         3
# Cámara digital            3
# Elementos de cerámica     3
# Espejo decorativo         3
# Freidora eléctrica        3
# Heladera                  3
# Horno eléctrico           3
# Jarrón decorativo         3
# Laptop                    3
# Lavadora                  3
# Lámpara de mesa           3
# Microondas                3
# Parlantes Bluetooth       3
# Plancha de vapor          3
# Proyector                 3
# Rincón de plantas         3
# Secadora                  3
# SmartWatch                3
# Smartphone                3
# Tablet                    3
# Televisor                 3
# Name: count, dtype: int64

# %%
# ordenamos los registros de "Marketing" en base a producto
df_marketing.sort_values(['producto']).head(30)
# Out:
#     id_campanha                producto  canal  costo fecha_inicio  fecha_fin
# 0            74         Adorno de pared     TV   4.81   2024-03-20 2024-05-03
# 8            44         Adorno de pared  Email   5.08   2024-04-13 2024-05-10
# 70           14         Adorno de pared   RRSS   4.16   2024-10-22 2024-12-21
# 84           28                Alfombra   RRSS   5.82   2024-11-27 2025-01-08
# 4            58                Alfombra  Email   4.25   2024-03-31 2024-05-05
# 41           88                Alfombra     TV   7.39   2024-07-25 2024-08-31
# 85           70              Aspiradora     TV   3.06   2024-12-13 2024-12-29
# 29           40              Aspiradora  Email   6.24   2024-06-24 2024-08-12
# 52           10              Aspiradora   RRSS   7.16   2024-08-19 2024-09-19
# 24           47             Auriculares  Email   4.19   2024-06-02 2024-07-22
# 35           17             Auriculares   RRSS   6.06   2024-07-15 2024-08-15
# ...

# %% [markdown]
# **Observación:**
#
# - hay 30 productos
# - cada producto tiene 3 repeticiones correspondientes a cada tipo de canal

# %% [markdown]
# ####***DataFrame 'Ventas'***

# %%
df_ventas['producto'].sort_values().value_counts()
# Out:
# producto
# Lámpara de mesa           176
# Auriculares               143
# Microondas                135
# Cafetera                  117
# Rincón de plantas         101
# Smartphone                101
# Cuadro decorativo         100
# Cortinas                  100
# Espejo decorativo         100
# Cámara digital            100
# Alfombra                  100
# Adorno de pared           100
# Aspiradora                100
# Batidora                  100
# Televisor                 100
# SmartWatch                100
# Secadora                  100
# Freidora eléctrica        100
# Lavadora                  100
# Laptop                    100
# Horno eléctrico           100
# Jarrón decorativo         100
# Plancha de vapor          100
# Proyector                  99
# Consola de videojuegos     99
# Elementos de cerámica      99
# Parlantes Bluetooth        98
# Tablet                     58
# Heladera                   48
# Candelabro                 24
# Name: count, dtype: int64

# %% [markdown]
# ####***Conclusión:***
# - el campo *'productos'* puedes ser utilizado para integrar los datos de ambas tablas
# - la organización de los datos de *'productos'* en ambos DataFrame es muy diferente:
#     - en *'Marketing'* es regular, presentando 3 repeticiones para cada canal y se indica lo gastado en la  promoción del producto en un periodo de tiempo determinado.
#       - Nº Registros: 90
#     - en *'ventas'* es irregular, registrandose para cada  eventos de venta de estos el precio, la  cantidad y la fecha.
#       - Nº Registros:2998
# - La unión de los DataFrame sin modificaciones previas traerám repeticiones y mostrarán datos poco ejemplificadores de la realidad (precisos).

# %% [markdown]
# ###***Integración de los DataFrame 'Ventas' y 'Marketing'***

# %%
# Integro los DataFrame 'Ventes' y 'Marketing' usando el campo 'producto'
ventas_marketing_1 = pd.merge(df_ventas,df_marketing, on='producto', how='inner')
ventas_marketing_1
# Out:
#       id_venta                producto  precio  cantidad fecha_venta  \
# 0          792       Cuadro decorativo   69.94       5.0  2024-01-02
# 1          792       Cuadro decorativo   69.94       5.0  2024-01-02
# 2          792       Cuadro decorativo   69.94       5.0  2024-01-02
# 3          811         Lámpara de mesa  105.10       5.0  2024-01-02
# 4          811         Lámpara de mesa  105.10       5.0  2024-01-02
# ...        ...                     ...     ...       ...         ...
# 8989      2913              Smartphone   99.85       7.0  2024-12-30
# 8990      2913              Smartphone   99.85       7.0  2024-12-30
# 8991      2930  Consola de videojuegos   55.47       6.0  2024-12-30
# 8992      2930  Consola de videojuegos   55.47       6.0  2024-12-30
# 8993      2930  Consola de videojuegos   55.47       6.0  2024-12-30
#
#         categoria  monto_venta  id_campanha  canal  costo fecha_inicio  \
# ...

# %% [markdown]
# ####***Observaciones y Conclusiones***
# **Observaciones:**
# - integración de DataFrames poco útil ya que:
#   - se repite cada registro de ventas para cada registro de marketing
#   - se repiten cada registro de marketing para cada producto vendido.
#
# **CONCLUSIÓN:**
# - La integración de estas tablas en bruto además de ser poco informativa puede llevar a una muy mala interpretación de los datos.
# - entre los posible usos que veo para la integración de los datos están:
#   - compartar los gastos de marketing vs. las ganacias para cada producto
#   - comparar las fechas de ventas y las de marketing para cada producto, para conocer si la estrategia de marketing fue efectiva
#   - similar a lo anterior pero analizado la efectividad de los canales en las ventas de productos

# %% [markdown]
# ###***Integración de los DataFrame 'Ventas' y 'Marketing' realizando transformaciones y agrupamientos de los datos***

# %% [markdown]
# **OBEJTIVO:**
#
# > **Comparar los Gastos de Marketing de cada producto vs las ganancias obtenidas por sus ventas**
#
# Para ello:
#
# 1. Crear un nuevo DataFrame en base a *'Marketing'* que para cada producto contenga:
#   - la suma de los costos de marketing de los 3 canales.
#     - **IMPORTANTE:** como las maginitudes de los costos de marketing estan en unidades, mientras que lor precios de *Ventas'* entas en decentas o cientos, **SE ASUME QUE LOS COSTOS ESTÁN EXPRESADOS EN MILES**.
#   - como *'fecha_inicio'* y *'fecha_fin'* se tamará la fecha mínima y máxima de la campaña de cada producto. Se tomará el periodo completo de publicidad independientemente del canal.
# 2. Crear un nuevo DataFrame en base a *'Ventas'* que para cada producto contenga:
#   - la categoría
#   - la suma de los montos de las ventas

# %% [markdown]
# ####***Nuevos DataFrame Marketing Producto***

# %%
# creo un nuevo DataFrame a partir de Marketing
df_MarketingProductos = df_marketing.groupby(['producto'], as_index=False).agg({
    "costo": "sum",
    "fecha_inicio": "min",
    "fecha_fin": "max"
})

# %%
# corrorobo nuevo DataFrame a partir de Ventas de Ventas
df_MarketingProductos
# Out:
#                   producto  costo fecha_inicio  fecha_fin
# 0          Adorno de pared  14.05   2024-03-20 2024-12-21
# 1                 Alfombra  17.46   2024-03-31 2025-01-08
# 2               Aspiradora  16.46   2024-06-24 2024-12-29
# 3              Auriculares  15.24   2024-06-02 2024-12-06
# 4                 Batidora  15.28   2024-04-10 2024-12-08
# 5                 Cafetera  18.16   2024-06-20 2024-10-11
# 6               Candelabro  14.65   2024-05-29 2024-11-16
# 7   Consola de videojuegos  12.77   2024-05-03 2024-11-20
# 8                 Cortinas  17.36   2024-05-02 2024-10-15
# 9        Cuadro decorativo  15.85   2024-04-27 2024-12-23
# 10          Cámara digital  16.40   2024-07-16 2024-12-09
# 11   Elementos de cerámica  16.87   2024-06-26 2024-10-12
# 12       Espejo decorativo  14.89   2024-05-31 2024-10-17
# 13      Freidora eléctrica  13.56   2024-06-05 2025-01-21
# 14                Heladera  13.11   2024-05-06 2024-08-09
# ...

# %%
# Según lo asumido de que los costos están expresados en miles, multiplico los costos por mil
df_MarketingProductos['costo'] = df_MarketingProductos['costo']*1000

# %%
# corroboro la modificación de 'costos'
df_MarketingProductos
# Out:
#                   producto    costo fecha_inicio  fecha_fin
# 0          Adorno de pared  14050.0   2024-03-20 2024-12-21
# 1                 Alfombra  17460.0   2024-03-31 2025-01-08
# 2               Aspiradora  16460.0   2024-06-24 2024-12-29
# 3              Auriculares  15240.0   2024-06-02 2024-12-06
# 4                 Batidora  15280.0   2024-04-10 2024-12-08
# 5                 Cafetera  18160.0   2024-06-20 2024-10-11
# 6               Candelabro  14650.0   2024-05-29 2024-11-16
# 7   Consola de videojuegos  12770.0   2024-05-03 2024-11-20
# 8                 Cortinas  17360.0   2024-05-02 2024-10-15
# 9        Cuadro decorativo  15850.0   2024-04-27 2024-12-23
# 10          Cámara digital  16400.0   2024-07-16 2024-12-09
# 11   Elementos de cerámica  16870.0   2024-06-26 2024-10-12
# 12       Espejo decorativo  14890.0   2024-05-31 2024-10-17
# 13      Freidora eléctrica  13560.0   2024-06-05 2025-01-21
# 14                Heladera  13110.0   2024-05-06 2024-08-09
# ...

# %% [markdown]
# ####***Nuevos DataFrame Venta Producto***

# %%
# creo un nuevo DataFrame a partir de Ventas
df_VentaProductos = df_ventas.groupby(['categoria', 'producto'], as_index=False)["monto_venta"].sum()

# %%
# corrorobo nuevo DataFrame a partir de Ventas de Ventas
df_VentaProductos
# Out:
#             categoria                producto  monto_venta
# 0          Decoración         Adorno de pared     48093.49
# 1          Decoración                Alfombra     44773.06
# 2          Decoración              Candelabro     11128.80
# 3          Decoración                Cortinas     44865.03
# 4          Decoración       Cuadro decorativo     54297.60
# 5          Decoración   Elementos de cerámica     45411.09
# 6          Decoración       Espejo decorativo     46783.31
# 7          Decoración       Jarrón decorativo     51130.88
# 8          Decoración         Lámpara de mesa     82276.38
# 9          Decoración       Rincón de plantas     50456.45
# 10  Electrodomésticos              Aspiradora     50085.86
# 11  Electrodomésticos                Batidora     50979.20
# 12  Electrodomésticos                Cafetera     59607.31
# 13  Electrodomésticos      Freidora eléctrica     50155.15
# 14  Electrodomésticos                Heladera     25736.80
# ...

# %% [markdown]
# ####***Integro los nuevos DataFrames***

# %%
# integración de los DataFrames 'df_MarketingProductos' y 'df_VentaProductos'
df_productos = pd.merge(df_VentaProductos, df_MarketingProductos, on='producto', how='inner')

# %%
# corroboro nuevo DataFrame
df_productos
# Out:
#             categoria                producto  monto_venta    costo  \
# 0          Decoración         Adorno de pared     48093.49  14050.0
# 1          Decoración                Alfombra     44773.06  17460.0
# 2          Decoración              Candelabro     11128.80  14650.0
# 3          Decoración                Cortinas     44865.03  17360.0
# 4          Decoración       Cuadro decorativo     54297.60  15850.0
# 5          Decoración   Elementos de cerámica     45411.09  16870.0
# 6          Decoración       Espejo decorativo     46783.31  14890.0
# 7          Decoración       Jarrón decorativo     51130.88  13270.0
# 8          Decoración         Lámpara de mesa     82276.38  15930.0
# 9          Decoración       Rincón de plantas     50456.45  16450.0
# 10  Electrodomésticos              Aspiradora     50085.86  16460.0
# 11  Electrodomésticos                Batidora     50979.20  15280.0
# 12  Electrodomésticos                Cafetera     59607.31  18160.0
# ...

# %% [markdown]
# ####***Análisis de Ganancias en nuevo DataFrame Integrado***

# %%
# agrego la columna ganancias como 'montos_venta' - 'costo'
df_productos['ganancia'] = df_productos['monto_venta'] - df_productos['costo']

# %%
# corroboro nueva columna
df_productos
# Out:
#             categoria                producto  monto_venta    costo  \
# 0          Decoración         Adorno de pared     48093.49  14050.0
# 1          Decoración                Alfombra     44773.06  17460.0
# 2          Decoración              Candelabro     11128.80  14650.0
# 3          Decoración                Cortinas     44865.03  17360.0
# 4          Decoración       Cuadro decorativo     54297.60  15850.0
# 5          Decoración   Elementos de cerámica     45411.09  16870.0
# 6          Decoración       Espejo decorativo     46783.31  14890.0
# 7          Decoración       Jarrón decorativo     51130.88  13270.0
# 8          Decoración         Lámpara de mesa     82276.38  15930.0
# 9          Decoración       Rincón de plantas     50456.45  16450.0
# 10  Electrodomésticos              Aspiradora     50085.86  16460.0
# 11  Electrodomésticos                Batidora     50979.20  15280.0
# 12  Electrodomésticos                Cafetera     59607.31  18160.0
# ...

# %%
df_productos.sort_values('ganancia')
# Out:
#             categoria                producto  monto_venta    costo  \
# 2          Decoración              Candelabro     11128.80  14650.0
# 14  Electrodomésticos                Heladera     25736.80  13110.0
# 28        Electrónica                  Tablet     25856.57  12720.0
# 1          Decoración                Alfombra     44773.06  17460.0
# 3          Decoración                Cortinas     44865.03  17360.0
# 5          Decoración   Elementos de cerámica     45411.09  16870.0
# 22        Electrónica          Cámara digital     45217.96  16400.0
# 23        Electrónica                  Laptop     46179.48  15190.0
# 18  Electrodomésticos        Plancha de vapor     45196.63  14120.0
# 6          Decoración       Espejo decorativo     46783.31  14890.0
# 26        Electrónica              SmartWatch     47836.86  14500.0
# 21        Electrónica  Consola de videojuegos     46174.41  12770.0
# 10  Electrodomésticos              Aspiradora     50085.86  16460.0
# ...

# %%
df_productos.groupby(['categoria'])['ganancia'].sum()
# Out:
# categoria
# Decoración           322436.09
# Electrodomésticos    360089.63
# Electrónica          340987.80
# Name: ganancia, dtype: float64

# %% [markdown]
# **Observación:**
# - el producto que más ganancia dio fueron las *'Lamparas de Mesa' (Decoración)*.
# - Los *'Candelabros' (Decoración)* fueron los únicos productos que dieron pérdida.
# - La categoría que más ganancia dió fue *'Electrodomésticos'*

# %% [markdown]
# #**Etapa 3: Análisis de Datos**

# %%
# Para recordar todos los DataFrame utilizads hasta ahora
# %who DataFrame
# Out:
# df_MarketingProductos	 df_VentaProductos	 df_clientes	 df_marketing	 df_productos	 df_productosTop	 df_tabla_Ventas	 df_ventas	 df_ventas_Categoria
# ventas_marketing_1

# %% [markdown]
# ##***Actividad 1: Estadística Descriptiva***

# %% [markdown]
# ### ***DataFrame Ventas***

# %% [markdown]
# #### ***Modificación del DataFrame Ventas***

# %% [markdown]
# Al DataFrame 'Ventas' se le agregaran los campos "mes" y "día_Semana" para realizar los análisis estadisticos en base a los meses y los días de la semana

# %%
# Agrego el campo "mes" al DataFrame 'Ventas'
df_ventas['mes'] = df_ventas['fecha_venta'].dt.month

# Agrego el campo "dia_semana" al DataFrame 'Ventas'
df_ventas['dia_semana'] = df_ventas['fecha_venta'].dt.day_name()

# Corroboro que se realizaron los cambios correctamente
df_ventas
# Out:
#       id_venta                producto  precio  cantidad fecha_venta  \
# 0          792       Cuadro decorativo   69.94       5.0  2024-01-02
# 1          811         Lámpara de mesa  105.10       5.0  2024-01-02
# 2         1156                Secadora   97.96       3.0  2024-01-02
# 3         1372                Heladera  114.35       8.0  2024-01-02
# 4         1546                Secadora  106.21       4.0  2024-01-02
# ...        ...                     ...     ...       ...         ...
# 2993      1837         Horno eléctrico  104.12       9.0  2024-12-30
# 2994      2276                  Laptop   85.27       9.0  2024-12-30
# 2995      2696                  Laptop  107.81       4.0  2024-12-30
# 2996      2913              Smartphone   99.85       7.0  2024-12-30
# 2997      2930  Consola de videojuegos   55.47       6.0  2024-12-30
#
#               categoria  monto_venta  mes dia_semana
# 0            Decoración       349.70    1    Tuesday
# ...

# %% [markdown]
# #### ***Estadísticas del DataFrame Ventas***

# %%
# Estadísticas generales del DataFrame Ventas
df_ventas[["precio", "cantidad", "monto_venta"]].describe()
# Out:
#             precio     cantidad  monto_venta
# count  2998.000000  2998.000000  2998.000000
# mean     75.291318     6.502668   489.357412
# std      28.736008     3.455107   334.281817
# min      26.000000     1.000000    26.300000
# 25%      50.030000     3.000000   220.920000
# 50%      75.205000     7.000000   418.065000
# 75%     100.067500     9.000000   709.920000
# max     124.970000    12.000000  1488.120000

# %% [markdown]
# #####***Estadísticas de Ventas por mes***

# %%
# Estadisticas del campo 'precio' agrupadas por mes
df_ventas.groupby("mes")[["precio"]].describe()
# Out:
#     precio
#      count       mean        std    min      25%     50%       75%     max
# mes
# 1    268.0  74.990075  29.726902  26.42  47.7425  78.910   99.7000  123.96
# 2    248.0  74.913790  28.744975  26.00  49.2300  74.645   99.9450  124.82
# 3    265.0  75.769547  28.922329  27.65  49.3700  76.150  101.5700  124.82
# 4    275.0  74.537055  29.726053  26.29  46.4850  73.700   98.2500  124.95
# 5    275.0  77.984982  28.949767  26.06  52.0850  78.440  104.5050  124.57
# 6    221.0  76.176516  28.471586  26.82  51.5100  74.810  103.1900  124.91
# 7    243.0  74.831770  27.301862  26.30  52.6200  74.880   97.1500  124.64
# 8    254.0  75.696654  27.595050  26.11  53.3325  75.965   96.5450  124.96
# 9    241.0  73.831826  28.924087  26.03  50.2000  71.400   97.1700  124.97
# 10   230.0  77.531435  29.486885  26.32  52.2675  77.105  104.0975  124.48
# 11   241.0  73.180830  28.437006  27.72  49.4700  70.550   98.1500  124.49
# ...

# %%
# Estadisticas del campo 'cantidad' agrupadas por mes
df_ventas.groupby("mes")[["cantidad"]].describe()
# Out:
#     cantidad
#        count      mean       std  min   25%  50%   75%   max
# mes
# 1      268.0  6.496269  3.465721  1.0  3.75  7.0   9.0  12.0
# 2      248.0  6.479839  3.464043  1.0  4.00  6.0  10.0  12.0
# 3      265.0  6.762264  3.672184  1.0  3.00  7.0  10.0  12.0
# 4      275.0  6.236364  3.482824  1.0  3.00  7.0   9.0  12.0
# 5      275.0  6.589091  3.431588  1.0  4.00  6.0  10.0  12.0
# 6      221.0  6.452489  3.478996  1.0  3.00  6.0   9.0  12.0
# 7      243.0  6.366255  3.585095  1.0  3.00  6.0   9.0  12.0
# 8      254.0  6.354331  3.466446  1.0  3.00  6.0   9.0  12.0
# 9      241.0  6.539419  3.247997  1.0  4.00  6.0   9.0  12.0
# 10     230.0  6.339130  3.482676  1.0  4.00  6.0  10.0  12.0
# 11     241.0  6.742739  3.450875  1.0  4.00  7.0  10.0  12.0
# 12     237.0  6.675105  3.214100  1.0  4.00  7.0   9.0  12.0

# %%
# Estadisticas del campo 'monto_ventas' agrupadas por mes
df_ventas.groupby("mes")[["monto_venta"]].describe()
# Out:
#     monto_venta                                                              \
#           count        mean         std    min       25%      50%       75%
# mes
# 1         268.0  483.600709  340.244520  29.17  220.3850  388.600  689.7900
# 2         248.0  478.517903  316.761425  31.09  225.9700  426.475  695.1600
# 3         265.0  516.147736  360.610738  31.42  224.8500  444.430  761.0400
# 4         275.0  467.020691  344.828281  29.68  184.1700  368.400  653.6850
# 5         275.0  522.644545  352.553560  29.73  221.4500  456.800  789.0300
# 6         221.0  490.860498  328.492216  33.73  210.8800  415.640  742.2100
# 7         243.0  478.312634  333.361886  26.30  218.7750  420.480  682.8850
# 8         254.0  471.181693  320.801691  36.21  221.1575  394.260  683.2850
# 9         241.0  480.447510  321.042204  34.56  237.7800  421.440  660.0600
# 10        230.0  487.465783  335.691883  38.69  209.2875  387.585  723.4325
# ...

# %% [markdown]
# #####***Estadísticas de Ventas por día de la semana***

# %%
# Estadisticas del campo 'precio' agrupadas por día de la semana
df_ventas.groupby("dia_semana")[["precio"]].describe()
# Out:
#            precio                                                          \
#             count       mean        std    min      25%     50%       75%
# dia_semana
# Friday      378.0  74.282143  28.370600  26.00  50.7025  73.795   97.9100
# Monday      418.0  76.357799  28.346499  26.24  50.8975  77.195  100.2550
# Saturday    444.0  74.836261  28.399973  26.11  51.3575  73.415   98.2325
# Sunday      447.0  76.615436  28.649518  26.06  51.6250  77.130  101.9300
# Thursday    435.0  75.523149  28.806071  26.29  49.9300  76.040   99.6550
# Tuesday     439.0  73.164897  28.743804  26.32  47.7700  69.940   97.7000
# Wednesday   437.0  76.157437  29.786111  26.20  49.0600  78.130  101.5800
#
#
#                max
# dia_semana
# Friday      124.97
# Monday      124.95
# Saturday    124.57
# Sunday      124.83
# Thursday    124.96
# Tuesday     124.91
# Wednesday   124.88

# %%
# Estadisticas del campo 'cantidad' agrupadas por día de la semana
df_ventas.groupby("dia_semana")[["cantidad"]].describe()
# Out:
#            cantidad
#               count      mean       std  min  25%  50%   75%   max
# dia_semana
# Friday        378.0  6.785714  3.437059  1.0  4.0  7.0  10.0  12.0
# Monday        418.0  6.208134  3.517306  1.0  3.0  6.0   9.0  12.0
# Saturday      444.0  6.531532  3.354374  1.0  4.0  7.0   9.0  12.0
# Sunday        447.0  6.463087  3.396497  1.0  3.0  6.0   9.0  12.0
# Thursday      435.0  6.786207  3.532312  1.0  4.0  7.0  10.0  12.0
# Tuesday       439.0  6.195900  3.446642  1.0  3.0  6.0   9.0  12.0
# Wednesday     437.0  6.576659  3.476884  1.0  4.0  7.0  10.0  12.0

# %%
# Estadisticas del campo 'monto_venta' agrupadas por día de la semana
df_ventas.groupby("dia_semana")[["monto_venta"]].describe()
# Out:
#            monto_venta                                                    \
#                  count        mean         std    min       25%      50%
# dia_semana
# Friday           378.0  506.526323  343.185778  28.91  233.6400  427.825
# Monday           418.0  476.207440  336.714459  29.17  184.2675  391.935
# Saturday         444.0  484.274550  322.534300  32.30  227.7400  422.190
# Sunday           447.0  491.545347  324.844616  31.42  234.5600  421.680
# Thursday         435.0  507.151149  336.120710  29.76  235.3850  443.520
# Tuesday          439.0  457.277950  330.222794  30.59  189.0300  374.730
# Wednesday        437.0  504.524989  346.634023  26.30  235.4200  418.330
#
#
#                  75%      max
# dia_semana
# Friday      723.1275  1458.72
# Monday      728.1300  1452.00
# Saturday    699.6825  1422.60
# Sunday      712.7800  1483.20
# Thursday    722.6850  1485.96
# Tuesday     665.3800  1488.12
# Wednesday   723.8000  1461.24

# %% [markdown]
# ### ***DataFrame Marketing***

# %%
# Estadisticas del campo 'costos'
df_marketing [["costo"]].describe()
# Out:
#            costo
# count  90.000000
# mean    4.928667
# std     0.947750
# min     2.950000
# 25%     4.372500
# 50%     4.900000
# 75%     5.562500
# max     7.390000

# %%
# Estadisticas del campo 'costos' agrupadas por canal
df_marketing.groupby("canal")[["costo"]].describe()
# Out:
#       costo
#       count      mean       std   min     25%    50%     75%   max
# canal
# Email  30.0  4.840000  0.898773  2.95  4.2125  4.895  5.5075  6.84
# RRSS   30.0  5.030333  0.894101  3.16  4.5600  5.130  5.5425  7.16
# TV     30.0  4.915667  1.063215  3.06  4.3725  4.795  5.5400  7.39

# %% [markdown]
# ##***Actividad 2: Análisis Exploratorio de Datos (EDA)***

# %%
# importamos las librerias para realizar los gráficos
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### ***Cantidad de Ventas por mes***

# %%
# Agrupamos por mes y agregamos por cantidad
cantidades_mes = df_ventas.groupby("mes", as_index=False).agg(cantidad_mes=("cantidad", "sum"))

# Visualizamos
cantidades_mes
# Out:
#     mes  cantidad_mes
# 0     1        1741.0
# 1     2        1607.0
# 2     3        1792.0
# 3     4        1715.0
# 4     5        1812.0
# 5     6        1426.0
# 6     7        1547.0
# 7     8        1614.0
# 8     9        1576.0
# 9    10        1458.0
# 10   11        1625.0
# 11   12        1582.0

# %%
# Crear el histograma
sns.barplot(data=cantidades_mes, x='mes', y='cantidad_mes', label="Ventas 2024", width=0.8)
# Out:
# <Axes: xlabel='mes', ylabel='cantidad_mes'>

# %% [markdown]
# #### ***Montos de ventas por mes***

# %%
montos_mes=df_ventas.groupby("mes", as_index=False).agg(monto_ventas_mes=("monto_venta", "sum"))

montos_mes
# Out:
#     mes  monto_ventas_mes
# 0     1         129604.99
# 1     2         118672.44
# 2     3         136779.15
# 3     4         128430.69
# 4     5         143727.25
# 5     6         108480.17
# 6     7         116229.97
# 7     8         119680.15
# 8     9         115787.85
# 9    10         112117.13
# 10   11         119951.79
# 11   12         117631.94

# %%
sns.lineplot(data=montos_mes, x="mes", y="monto_ventas_mes", label="Montos de ventas mesuales")
# Out:
# <Axes: xlabel='mes', ylabel='monto_ventas_mes'>

# %% [markdown]
# #### ***Montos de ventas por día de semana***

# %%
# Medidas de dispersión de los montos de ventas por día de la semana

orden_dias = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

plt.figure(figsize=(12, 6))
sns.boxplot(data=df_ventas, x="dia_semana", y="monto_venta", order=orden_dias)
plt.title("Boxplot de Monto de Ventas por Día de la Semana")
plt.xlabel("Día de la semana")
plt.ylabel("Monto de venta")
plt.show()

# %% [markdown]
# #### ***Cantidades de ventas por día de semana***

# %%
# Medidas de dispersión de las cantidades de ventas por día de la semana

plt.figure(figsize=(12, 6))
sns.boxplot(data=df_ventas, x="dia_semana", y="cantidad", order=orden_dias)
plt.title("Boxplot de Cantidades de Ventas por Día de la Semana")
plt.xlabel("Día de la semana")
plt.ylabel("Cantidad de venta")
plt.show()

# %% [markdown]
# #### ***Lamparas de Mesa vendidas por mes***

# %% [markdown]
# Las "Lámaparas de Mesa" fueron el producto que más ganancia dio, es por ello que trabajaremos particularmente con este producto viendo sus ventas a lo largo de los meses.

# %%
# Creamos un nuevo DataFrame para las ventas de "Lámpara de mesa" por mes
df_lamparas_mes = (df_ventas[df_ventas["producto"] == "Lámpara de mesa"].groupby("mes", as_index=False).agg({"cantidad": "sum", "monto_venta": "sum"}))

df_lamparas_mes
# Out:
#     mes  cantidad  monto_venta
# 0     1     120.0      9194.25
# 1     2     108.0      7319.77
# 2     3     101.0      7769.16
# 3     4     154.0     12383.81
# 4     5     113.0      9096.28
# 5     6      44.0      3985.49
# 6     7      94.0      6277.59
# 7     8      61.0      4007.08
# 8     9      70.0      4740.24
# 9    10      20.0      1433.86
# 10   11     119.0      8596.93
# 11   12     108.0      7471.92

# %%
sns.lineplot(data=df_lamparas_mes, x="mes", y="cantidad", label="Lamparas: Cantidad de ventas mesuales")
# Out:
# <Axes: xlabel='mes', ylabel='cantidad'>

# %% [markdown]
# ##***Actividad 3: Correlación***

# %% [markdown]
# ### ***Precio de Productos vs Cantidad de productos vendidos***

# %%
# Exploramos las correlaciones entre las distintas variables numéricas del DataFrame 'Ventas' calculando una matríz de correlación
correlacion = df_ventas[['precio', 'cantidad', 'monto_venta']].corr()
print(correlacion)
# Out:
#                precio  cantidad  monto_venta
# precio       1.000000 -0.002388     0.558846
# cantidad    -0.002388  1.000000     0.773009
# monto_venta  0.558846  0.773009     1.000000

# %% [markdown]
# La correlaciones diferentes de cero son:
#  monto_venta y precio, lo cual es entendible, ya que
#
# 1.   ***monto_venta y precio***,
# 2.   ***monto_venta y cantidad***,
#
# lo cual es entendible, ya que monto_venta = precio * cantidad.
#
# >*No se observó que el precio de los productos afectara la cantidad de unidades vendidas*

# %% [markdown]
# ### ***Costos de Marketing vs Montos de ventas***

# %%
# Calculamos la matriz de correlacion entre "monto_venta" y "costo" del DataFrame df_productos
df_productos[["monto_venta", "costo"]].corr()
# Out:
#              monto_venta     costo
# monto_venta     1.000000  0.242179
# costo           0.242179  1.000000

# %%
# Graficamos la relación entre estas dos variables
sns.scatterplot(data=df_productos, x="costo", y="monto_venta")
plt.title("Relación entre Costos de Marketing y Montos de Ventas")
plt.xlabel("Costo de Marketing")
plt.ylabel("Monto de Ventas")
plt.show()

# %% [markdown]
# ##***Actividad 4: Consolidación de Datos***

# %% [markdown]
# #**Etapa 4: Consolidación de Datos**

# %% [markdown]
# ##***Actividad 1: Visualización con Matplotlib***

# %% [markdown]
# ##***Actividad 2: Visualización Avanzada con Seaborn***

# %% [markdown]
# ##***Actividad 3: Visualización Interactiva con Plotly***

# %% [markdown]
# ##***Actividad 4: Presentación Final***

# %% [markdown]
# #**Anexo**

# %% [markdown]
# **Bases de datos utilizadas:**
# - [clientes.csv](https://github.com/FedeM-Git/TT-2C2025-Data-Analitycs-Notebooks/blob/main/Pre-Entrega_Maune/datasets/clientes.csv)
# - [marketing.csv](https://github.com/FedeM-Git/TT-2C2025-Data-Analitycs-Notebooks/blob/main/Pre-Entrega_Maune/datasets/marketing.csv)
# - [ventas.csv](https://github.com/FedeM-Git/TT-2C2025-Data-Analitycs-Notebooks/blob/main/Pre-Entrega_Maune/datasets/ventas.csv)

# %%
ventas_marketing_1.head()
